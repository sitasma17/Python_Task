# %% [markdown]
# # **Task 7 Solution-Sitasma Karki**

# %% [markdown]
# # Function with Default Argument

# %% [markdown]
# Question: Create a function greet(name, message="Welcome!") that prints: "Hello, <name>! <message>"

# %%
def greet(name, message="Welcome!"):
  print(f"Hello, {name}! {message}")
greet('Sitasma')
greet('Sitasma', 'Good Morning!')
# Out:
# Hello, Sitasma! Welcome!
# Hello, Sitasma! Good Morning!

# %% [markdown]
# # Function with args (Variable Number of Arguments)

# %% [markdown]
# Question: Create a function total(*numbers) that takes any number of numeric arguments and returns their sum.

# %%
def total(*numbers):
  return sum(numbers)
print(total(3,4,5))
# Out:
# 12

# %% [markdown]
# # Function with kwargs (Keyword Arguments)

# %% [markdown]
# Question: Create a function display_info(**details) that prints key-value pairs.

# %%
def display_info(**details):
  for key, value in details.items():
        print(f"{key}: {value}")
display_info(name='Sitasma', age=20, city='Chitwan')
# Out:
# name: Sitasma
# age: 20
# city: Chitwan

# %% [markdown]
# # Function Using Both args and a Default Argument

# %% [markdown]
# Question: Create a function repeat_words(*words, times=2) that repeats each word the given number of times.

# %%
def repeat_words(*words,times=2):
  for word in words:
        print(word * times)
repeat_words('Data', 'Science', times=3)
# Out:
# DataDataData
# ScienceScienceScience

# %% [markdown]
# # Function Using All Types of Parameters Together

# %% [markdown]
# Question: Create a function user_profile(name, age=18, *hobbies, **extra_info) that:
#
#
# Prints the name and age
#
# Prints all hobbies (if any)
#
# Prints any additional info passed via **kwargs

# %%
def user_profile(name, age=18, *hobbies, **extra_info):
  print(f'Name:{name}')
  print(f"Age:{age}")
  if hobbies:
    print('Hobbies:')
    for hobby in hobbies:
      print(f"{hobby}")
  if extra_info:
    print("Additional Info:")
    for key, value in extra_info.items():
            print(f"  {key}: {value}")
user_profile('Sitasma', 20, 'Dancing', 'Reading', city='Chitwan')
# Out:
# Name:Sitasma
# Age:20
# Hobbies:
# Dancing
# Reading
# Additional Info:
#   city: Chitwan
